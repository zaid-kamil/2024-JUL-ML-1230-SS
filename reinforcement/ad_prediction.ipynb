# %%
import pandas as pd
import thompson as th

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/refs/heads/main/reinforcement/Ads_CTR_Optimisation.csv")
df

# %%
random_results = th.UCB_random(df)
th.plot(random_results)

# %%
ucb_results = th.UCB(df)
th.plot(ucb_results)

# %%
thompson_results = th.thompson(df)
th.plot(thompson_results)
